# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12123, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 12123 (delta 41), reused 57 (delta 27), pack-reused 12047
# Receiving objects: 100% (12123/12123), 12.56 MiB | 39.22 MiB/s, done.
# Resolving deltas: 100% (8334/8334), done.
# /content/yolov5
#      |████████████████████████████████| 1.6 MB 37.5 MB/s
#      |████████████████████████████████| 145 kB 31.4 MB/s
#      |████████████████████████████████| 178 kB 68.8 MB/s
#      |████████████████████████████████| 1.1 MB 66.4 MB/s
#      |████████████████████████████████| 67 kB 7.5 MB/s
#      |████████████████████████████████| 54 kB 3.3 MB/s
#      |████████████████████████████████| 138 kB 97.0 MB/s
#      |████████████████████████████████| 62 kB 1.8 MB/s
# ...
# Setup complete. Using torch 1.12.1+cu113 (CPU)

# %%
# !unzip -q ../coral-identification-dataset.zip -d .

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data data.yaml --weights yolov5s.pt --cfg yolov5s-custom.yaml --cache
# Out:
# train: weights=yolov5s.pt, cfg=yolov5s-custom.yaml, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-73-g91a81d4 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# ...

# %%
# test video
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.5 --source ../test/videos
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# video 1/3 (607/940) /content/test/videos/Acanthophyllia.mp4: 256x416 (no detections), 99.9ms
# video 1/3 (608/940) /content/test/videos/Acanthophyllia.mp4: 256x416 3 Cynarinas, 102.8ms
# video 1/3 (609/940) /content/test/videos/Acanthophyllia.mp4: 256x416 2 Cynarinas, 101.7ms
# video 1/3 (610/940) /content/test/videos/Acanthophyllia.mp4: 256x416 1 Cynarina, 103.9ms
# video 1/3 (611/940) /content/test/videos/Acanthophyllia.mp4: 256x416 1 Cynarina, 104.5ms
# video 1/3 (612/940) /content/test/videos/Acanthophyllia.mp4: 256x416 1 Cynarina, 103.4ms
# video 1/3 (613/940) /content/test/videos/Acanthophyllia.mp4: 256x416 3 Cynarinas, 99.9ms
# video 1/3 (614/940) /content/test/videos/Acanthophyllia.mp4: 256x416 2 Cynarinas, 103.5ms
# video 1/3 (615/940) /content/test/videos/Acanthophyllia.mp4: 256x416 2 Cynarinas, 102.7ms
# video 1/3 (616/940) /content/test/videos/Acanthophyllia.mp4: 256x416 1 Cynarina, 100.4ms
# ...

# %%
# test images
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.5 --source ../test/images/
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../test/images/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-73-g91a81d4 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# YOLOv5s-custom summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/30 /content/test/images/Acanthophyllia-Coral-Photos---Free--1-_jpg.rf.e8a5fe22d0a17f15f0a0df3d2e7aaab3.jpg: 416x416 1 Acanthophyllia, 276.8ms
# image 2/30 /content/test/images/Acanthophyllia-Coral-Photos---Free--2-_jpg.rf.f8c153813881e926227dfff8bd14f5f2.jpg: 416x416 1 Acanthophyllia, 266.9ms
# ...

# %%
# display predicted images
import glob
from IPython.display import Image, display

for imageName in glob.glob('runs/detect/ex2/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
# !zip -r images_result_predict.zip runs/detect/exp2
# !zip -r videos_result_predict.zip runs/detect/exp
# Out:
#   adding: runs/detect/exp2/ (stored 0%)
#   adding: runs/detect/exp2/Tag_-acanthophyllia-_-Reef-Builders--1-_jpg.rf.ae3c627bf4aca9e689a384604568d299.jpg (deflated 2%)
#   adding: runs/detect/exp2/Red-Acanthophyllia-Small---Shipwrecked--1-_jpeg.rf.0549d8da91e7d063b694188598c5af45.jpg (deflated 3%)
#   adding: runs/detect/exp2/Kryptonite-Candy-Cane--Caulastrea_jpg.rf.7cc793031ed7a7111106cf3836df49af.jpg (deflated 3%)
#   adding: runs/detect/exp2/Jual-coral-sinarina-_-Shopee-Indonesia--1-_jpg.rf.16802b240428c6318e7089174a68d651.jpg (deflated 4%)
#   adding: runs/detect/exp2/Green-Acanthophyllia-Meat-Coral-in--1-_jpg.rf.d25e6cd519a607c9587bcbe432600685.jpg (deflated 3%)
#   adding: runs/detect/exp2/Color-Caulastrea_jpg.rf.9949a8538e8034be01a288b959b162f6.jpg (deflated 3%)
#   adding: runs/detect/exp2/Acanthophyllia-deshayesiana---1---Reef--1-_jpg.rf.719a965cec4283a483dee043deb07bbc.jpg (deflated 3%)
# ...

# %%
# !python export.py --weights runs/train/exp/weights/best.pt --include tflite
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v6.2-73-g91a81d4 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# YOLOv5s-custom summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/exp/weights/best.pt with output shape (1, 25200, 8) (13.7 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.8.2...
#
#                  from  n    params  module                                  arguments
# 2022-08-30 07:47:33.485144: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !zip -r best_saved_model.zip runs/train/exp/weights/best_saved_model
# Out:
#   adding: runs/train/exp/weights/best_saved_model/ (stored 0%)
#   adding: runs/train/exp/weights/best_saved_model/saved_model.pb (deflated 8%)
#   adding: runs/train/exp/weights/best_saved_model/assets/ (stored 0%)
#   adding: runs/train/exp/weights/best_saved_model/variables/ (stored 0%)
#   adding: runs/train/exp/weights/best_saved_model/variables/variables.data-00000-of-00001 (deflated 4%)
#   adding: runs/train/exp/weights/best_saved_model/variables/variables.index (deflated 33%)
